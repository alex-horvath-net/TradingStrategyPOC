# %% [markdown]
# - visit python.org/download
# - python --version
# - download vscode

# %%
import yfinance as yf # Version: 0.2.38
import pandas as pd   # Version: 2.2.2
import plotly.graph_objects as go # Version: 5.22.0
import matplotlib.pyplot as pp # Version: 3.9.0

# %%
#Download historical data
ticker_symbol = "BTC-USD"
period= "100d"
start = "2024-01-01"
end = "2024-01-31"
interval = "1d"
raw_data_file_path= "asdf.csv"
ticker = yf.Ticker(ticker_symbol)
historical_data = ticker.history(start=start, end=end, interval=interval)
historical_data = historical_data[ historical_data["Volume"]!=0 ] # clean empty volumes
#historical_data = ticker.history(period=period, interval=interval)
#historical_data = pd.read_csv(raw_data_file_path)

# %%
#clean data
df = historical_data[0:100]

# %%
#pyplot
pp.plot(  df.index, df.Close,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12)
pp.show()

# %%
candlestick = go.Candlestick(x=df.index, open=df['Open'], high=df['High'], low=df['Low'], close=df['Close'])
fig = go.Figure(data=candlestick)

fig.update_layout(paper_bgcolor="black", plot_bgcolor="black", 
                  margin_l=10, margin_b=0, margin_r=0, margin_t=0, grid_columns=1,grid_rows=1)

# %%
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='black')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='black')
fig.show()
